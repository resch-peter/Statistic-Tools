# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from iminuit import Minuit, cost
import healpy as hp

from matplotlib.markers import MarkerStyle

my_cmap = plt.colormaps["rainbow"]
my_marker=MarkerStyle(marker="1", fillstyle='full', transform=None, capstyle=None, joinstyle=None)
plt.rcParams['font.family'] = 'serif'
plt.rcParams['savefig.dpi']=600
plt.rcParams["savefig.bbox"]='tight'
plt.rcParams["figure.figsize"]='5,3'
text_style = dict(horizontalalignment='right', verticalalignment='center',
                  fontsize=12, fontfamily='monospace')

r = np.random
r.seed(42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from scipy import stats
#       6 from iminuit import Minuit, cost
# ----> 7 import healpy as hp
#       9 from matplotlib.markers import MarkerStyle
#      11 my_cmap = plt.colormaps["rainbow"]
#
# ModuleNotFoundError: No module named 'healpy'

# %% [markdown]
# ## #11 AutoCorrelation
#
# #1 generating data

# %%
N_points = 10

u = r.rand(N_points)
v = r.rand(N_points)
theta = 2 * np.pi * u
phi = np.arccos(2*v-1)
x   = np.sin(theta) * np.cos(phi)
y   = np.sin(theta) * np.sin(phi)
z   = np.cos(theta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 N_points = 10
# ----> 3 u = r.rand(N_points)
#       4 v = r.rand(N_points)
#       5 theta = 2 * np.pi * u
#
# NameError: name 'r' is not defined
